# %% [markdown]
# 1) Crie um programa que compara duas strings e veja se elas são iguais.

# %%
frase1 = input("Digite uma frase: ")
frase2 = input("Digite outra ou a mesma frase: ")

if frase1.lower() == frase2.lower(): #boas práticas: colocar o upper ou lower no if e não no input
  print("As frases escritas são iguais!")
else:
  print("As frases escritas são diferentes!")
# Out:
# Escreva uma frase: ola
# Escreva outra ou a mesma frase: Ola
# As frases escritas são iguais!

# %% [markdown]
# 2) Faça um programa que leia um nome completo e imprima as 4 primeiras letras do nome.

# %%
nome = input("Digite seu nome completo: ")

print(f"As 4 primeiras letras do seu nome são: {nome[0:4]}")
# Out:
# Digite seu nome completo: Giovana de Brito Silva
# As 4 primeiras letras do seu nome são: Giov

# %% [markdown]
# 3) Com o mesmo nome da questão 2, agora verifique a quantidade de caracteres que contém o nome digitado.

# %%
nome_sem_espaco = nome.replace(" ", "")

print(f"O nome {nome} tem {len(nome_sem_espaco)} letras.")
# Out:
# O nome Giovana de Brito Silva tem 19 letras.

# %% [markdown]
# 4) Leia uma frase qualquer e verifique se a pessoa digitou a palavra “cachorro” nessa frase (Não importa a maneira como a pessoa escreveu)

# %%
frase = input("Digite uma frase qualquer: ")

if "cachorro" in frase.lower(): #boas práticas: colocar o upper ou lower no if e não no input
  print("A palavra cachorro está nessa frase!")
else: 
  print("A palavra cachorro não está nessa frase!")
# Out:
# Digite uma frase qualquer: o Dog é doido
# A palavra cachorro não está nessa frase!

# %% [markdown]
# 5) Crie um programa que leia uma string e mostre a string de trás pra frente até o 6º caractere

# %%
frase = input("Digite uma frase qualquer: ")

print(frase[-1:-7:-1])
# Out:
# Digite uma frase qualquer: ola tudo bem
# meb od
# do bem

# %% [markdown]
# 6) Faça um programa que conte o numero de 1’s que aparecem em um string. Exemplo: ´ 0011001 -> 3

# %%
num_bin = "0011001"

print(num_bin.count("1"))
# Out:
# 3

# %% [markdown]
# 7) Escreva um programa que substitui as ocorrências de um caractere 0 em uma string por ˆ outro caractere 1.

# %%
num_bin = "0011001"

print(num_bin.replace("0", "1"))
# Out:
# 1111111

# %% [markdown]
# 8) Faça um programa em que troque todas as ocorrências de uma letra L1 pela letra L2 em ˆ uma string. A string e as letras L1 e L2 devem ser fornecidas pelo usuario.

# %%
frase = input("Digite uma frase qualquer: ")
letra1 = input("Digite uma letra para ser alterada da frase: ")
letra2 = input("Digite qual será a letra que fará a alteração: ")

frase2 = frase.replace(letra1, letra2)

print(f"Sua frase final é: {frase2}")
# Out:
# Digite uma frase qualquer: oi tudo bem com você
# Digite uma letra para ser alterada da frase: o
# Digite qual será a letra que fará a alteração: a
# Sua frase final é: ai tuda bem cam vacê

# %% [markdown]
# 9) Faça um programa que receba duas frases distintas e imprima de maneira invertida, trocando as letras A por *.

# %%
frase1 = input("Digite uma frase: ")
frase2 = input("Digite outra frase: ")



print(frase1[-1::-1].upper().replace("A", "*"))
print(frase2[-1::-1].upper().replace("A", "*"))
# Out:
# Digite uma frase: ola como vai voce
# Digite outra frase: eu vou bem, e sua filha
# ECOV I*V OMOC *LO
# *HLIF *US E ,MEB UOV UE

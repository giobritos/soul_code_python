# %% [markdown]
# 1) Faça um Programa que leia uma lista de 5 números inteiros e mostre-os.

# %%
lst = []

for i in range(5):
  num = int(input(f'Digite o {i+1}º número inteiro de sua preferência: '))
  
  lst.append(num)
  
print('\n')
print(lst)
# Out:
# Digite o 1º número inteiro de sua preferência: 1
# Digite o 2º número inteiro de sua preferência: 9
# Digite o 3º número inteiro de sua preferência: 7
# Digite o 4º número inteiro de sua preferência: 3
# Digite o 5º número inteiro de sua preferência: 6
#
#
# [1, 9, 7, 3, 6]

# %%
# solução professor
numeros = []

for i in range(5):
  numeros.append(int(input(f'Digite o {i+1}º número inteiro de sua preferência: ')))

print('\n') 
 
for x in numeros:
  print(x, end = " ")
  
print('\n')

# também podemos usar:
for i in range(5):
  print(numeros[i], end = ' ')
# Out:
# Digite o 1º número inteiro de sua preferência: 1
# Digite o 2º número inteiro de sua preferência: 9
# Digite o 3º número inteiro de sua preferência: 7
# Digite o 4º número inteiro de sua preferência: 3
# Digite o 5º número inteiro de sua preferência: 6
#
#
# 1 9 7 3 6
#
# 1 9 7 3 6

# %% [markdown]
# 2) Faça um Programa que leia uma lista de 10 números reais e mostre-os na ordem inversa.

# %%
lst = []

for i in range(10):
  num = float(input(f'Digite o {i+1}º número real de sua preferência: '))
  
  lst.append(num)

print('\n')
lst.reverse()
print(lst)
# Out:
# Digite o 1º número real de sua preferência: 5
# Digite o 2º número real de sua preferência: 8
# Digite o 3º número real de sua preferência: 4
# Digite o 4º número real de sua preferência: 9
# Digite o 5º número real de sua preferência: 7
# Digite o 6º número real de sua preferência: 3
# Digite o 7º número real de sua preferência: 6
# Digite o 8º número real de sua preferência: 1
# Digite o 9º número real de sua preferência: 7
# Digite o 10º número real de sua preferência: 2
#
#
# [2.0, 7.0, 1.0, 6.0, 3.0, 7.0, 9.0, 4.0, 8.0, 5.0]

# %%
# solução professor
numeros = []

for i in range(10):
  numeros.append(float(input(f'Digite o {i+1}º número real de sua preferência: ')))
numeros.reverse()

print('\n')

for x in numeros:
  print(x, end = ' ')
# Out:
# Digite o 1º número real de sua preferência: 5
# Digite o 2º número real de sua preferência: 8
# Digite o 3º número real de sua preferência: 4
# Digite o 4º número real de sua preferência: 9
# Digite o 5º número real de sua preferência: 7
# Digite o 6º número real de sua preferência: 3
# Digite o 7º número real de sua preferência: 6
# Digite o 8º número real de sua preferência: 1
# Digite o 9º número real de sua preferência: 7
# Digite o 10º número real de sua preferência: 2
#
#
# 2.0 7.0 1.0 6.0 3.0 7.0 9.0 4.0 8.0 5.0

# %% [markdown]
# 3) Faça um Programa que leia 4 notas de aluno e armazene-as dentro de uma lista. Em seguida mostre as notas e a média das notas na tela.

# %%
notas = []
soma = 0

for i in range(4):
  nota = float(input(f'Digite a {i+1}ª nota: '))
  
  notas.append(nota)
  soma += nota
  media = soma / 4

print('\n')
print(f'Suas notas foram: {notas[0]}, {notas[1]}, {notas[2]}, {notas[3]}.')
print(f'A média das notas listadas é de: {media:.2f}')
# Out:
# Digite a 1ª nota: 7
# Digite a 2ª nota: 10
# Digite a 3ª nota: 8.5
# Digite a 4ª nota: 9
#
#
# Suas notas foram: 7.0, 10.0, 8.5, 9.0.
# A média das notas listadas é de: 8.62

# %%
# solução professor
notas = []
soma = 0

for i in range(4):
  n = float(input(f"Digite a {i+1}ª nota do aluno: "))
  while n < 0 or n > 10:
    n = float(input(f"Nota inválida! Digite novamente a {i+1}ª nota do aluno: "))
  
  notas.append(n)
  soma += notas[i]
media = soma / len(notas)

print('\n')
print('Notas do aluno: ')

for x in notas:
  print(f'{x}', end = ', ')

print('\n')
print(f'A média do aluno foi: {media:.2f}')
# Out:
# Digite a 1ª nota do aluno: 7
# Digite a 2ª nota do aluno: 8
# Digite a 3ª nota do aluno: 6
# Digite a 4ª nota do aluno: 7
#
#
# Notas do aluno:
# 7.0, 8.0, 6.0, 7.0,
#
# A média do aluno foi: 7.00

# %% [markdown]
# 4) Faça um Programa que leia 20 números inteiros e armazene-os numa lista. Em seguida, crie mais 2 listas, uma para armazenar os números pares e outra para armazenar os números impares. Ao final, Imprima as três listas.

# %%
lista = []
lista_par = []
lista_impar = []

for i in range(20):
  num = int(input(f'Digite o {i+1}º número inteiro de sua preferência: '))
  while num <= 0:
    num = int(input(f'Número inválido. Digite o {i+1}º número inteiro de sua preferência: '))
  
  lista.append(num)

  if num % 2 == 0:
    lista_par.append(num)
  else:
    lista_impar.append(num)
  
print('\n')
print(f"Lista geral: {lista}")
print(f"Lista par: {lista_par}")
print(f"Lista ímpar: {lista_impar}")
# Out:
# Digite o 1º número inteiro de sua preferência: 0
# Número inválido. Digite o 1º número inteiro de sua preferência: 8
# Digite o 2º número inteiro de sua preferência: 1
# Digite o 3º número inteiro de sua preferência: 4
# Digite o 4º número inteiro de sua preferência: 95
# Digite o 5º número inteiro de sua preferência: 3
# Digite o 6º número inteiro de sua preferência: 66
# Digite o 7º número inteiro de sua preferência: 77
# Digite o 8º número inteiro de sua preferência: 45
# Digite o 9º número inteiro de sua preferência: 8
# Digite o 10º número inteiro de sua preferência: 9
# Digite o 11º número inteiro de sua preferência: 12
# Digite o 12º número inteiro de sua preferência: 11
# Digite o 13º número inteiro de sua preferência: 10
# Digite o 14º número inteiro de sua preferência: 7
# Digite o 15º número inteiro de sua preferência: 2
# Digite o 16º número inteiro de sua preferência: 3
# Digite o 17º número inteiro de sua preferência: 18
# Digite o 18º número inteiro de sua preferência: 55
# Digite o 19º número inteiro de sua preferência: 67
# Digite o 20º número inteiro de sua preferência: 99
#
#
# Lista geral: [8, 1, 4, 95, 3, 66, 77, 45, 8, 9, 12, 11, 10, 7, 2, 3, 18, 55, 67, 99]
# Lista par: [8, 4, 66, 8, 12, 10, 2, 18]
# Lista ímpar: [1, 95, 3, 77, 45, 9, 11, 7, 3, 55, 67, 99]

# %%
# solução professor
numeros = []
for i in range(6):
  numeros.append(int(input(f'Digite o {i+1}º número: ')))

numeros_pares = []
numeros_impares = []

for x in numeros:
  if x % 2 == 0:
    numeros_pares.append(x)
  else:
    numeros_impares.append(x)

print('\n')
for a in numeros:
  print(a, end = ' ')
print('\n')
for b in numeros_pares:
  print(b, end = ' ')
print('\n')
for c in numeros_impares:
  print(c, end = ' ')
# Out:
# Digite o 1º número: 4
# Digite o 2º número: 8
# Digite o 3º número: 6
# Digite o 4º número: 3
# Digite o 5º número: 1
# Digite o 6º número: 2
#
#
# 4 8 6 3 1 2
#
# 4 8 6 2
#
# 3 1

# %% [markdown]
# 5) Faça um Programa que peça as quatro notas de 10 alunos junto com o seu nome. Calcule e armazene numa lista a média de cada aluno, bem como em outra lista armazene o nome do aluno. Ao final imprima o número de alunos com média maior ou igual a 7.0 junto com o seu nome e a média.

# %%
nomes = []
medias = []
n = 0

for i in range(4):
  aluno = input(f"\nDigite o nome do {i+1}º aluno: ")
  nomes.append(aluno)
  n1 = float(input("Digite a nota 1: "))
  while n1 < 0 or n1 > 10:
    n1 = float(input("Nota inválida! Digite novamente a nota 1 do aluno: "))
  n2 = float(input("Digite a nota 2: "))
  while n2 < 0 or n2 > 10:
    n2 = float(input("Nota inválida! Digite novamente a nota 2 do aluno: "))
  n3 = float(input("Digite a nota 3: "))
  while n3 < 0 or n3 > 10:
    n3 = float(input("Nota inválida! Digite novamente a nota 2 do aluno: "))
  n4 = float(input("Digite a nota 4: "))
  while n4 < 0 or n4 > 10:
    n4 = float(input("Nota inválida! Digite novamente a nota 2 do aluno: "))
       
  calc_media = (n1 + n2 + n3 + n4) / 4
  medias.append(calc_media)

  if calc_media >= 7:
    n += 1

print("\n")
print(f"Totalizando {n} aluno(s) com média maior ou igual a 7.00.")

for i in medias:
  if i >= 7:
    j = medias.index(i)
    print(f'O(A) aluno(a) {nomes[j]} teve média {medias[j]:.2f}.')
# Out:
# Digite o nome do 1º aluno: Giovana
# Digite a nota 1: 9
# Digite a nota 2: 10
# Digite a nota 3: 8.5
# Digite a nota 4: 7.5
#
# Digite o nome do 2º aluno: Rafael
# Digite a nota 1: 8.5
# Digite a nota 2: 7
# Digite a nota 3: 9.6
# Digite a nota 4: 6.9
#
# Digite o nome do 3º aluno: Mateus
# Digite a nota 1: 4.5
# Digite a nota 2: 5
# Digite a nota 3: 5.5
# Digite a nota 4: 7
#
# Digite o nome do 4º aluno: Nayara
# Digite a nota 1: 7
# Digite a nota 2: 5.5
# Digite a nota 3: 4.5
# Digite a nota 4: 10
#
#
# Totalizando 2 aluno(s) com média maior ou igual a 7.00.
# O(A) aluno(a) Giovana teve média 8.75.
# O(A) aluno(a) Rafael teve média 8.00.

# %%
# solução professor
nomes = []
medias = []

for i in range(3):
  soma = 0
  nomes.append(input(f'\nDigite o nome do {i+1}º aluno: '))
  #nomes[i] = input(f'Digite o nome do {i+1}º aluno: ')
  for j in range(4):
    nota = float(input(f'Digite a {j+1}ª nota do {i+1}º aluno: '))
    while nota < 0 or nota > 10:
      nota = float(input(f'Digite a {j+1}ª nota do {i+1}º aluno: '))
    soma += nota
  med = soma / 4
  medias.append(med)

qtd_maior_media = 0
for i in range(len(nomes)):
  if medias[i] >= 7:
    print("\n")
    print(f'O aluno {nomes[i]} foi aprovado com a média {medias[i]}')
    qtd_maior_media += 1

print("\n")
print(f"A quantidade de alunos que estão acima da média é {qtd_maior_media}.")
# Out:
# Digite o nome do 1º aluno: Giovana
# Digite a 1ª nota do 1º aluno: 8
# Digite a 2ª nota do 1º aluno: 8.5
# Digite a 3ª nota do 1º aluno: 9
# Digite a 4ª nota do 1º aluno: 9.5
#
# Digite o nome do 2º aluno: Rafael
# Digite a 1ª nota do 2º aluno: 9
# Digite a 2ª nota do 2º aluno: 7
# Digite a 3ª nota do 2º aluno: 6.5
# Digite a 4ª nota do 2º aluno: 7.5
#
# Digite o nome do 3º aluno: Luis
# Digite a 1ª nota do 3º aluno: 5
# Digite a 2ª nota do 3º aluno: 5.5
# Digite a 3ª nota do 3º aluno: 6.5
# Digite a 4ª nota do 3º aluno: 7
#
#
# O aluno Giovana foi aprovado com a média 8.75
#
#
# O aluno Rafael foi aprovado com a média 7.5
#
#
# A quantidade de alunos que estão acima da média é 2.

# %% [markdown]
# 6) Faça um Programa que leia uma lista de 5 números inteiros. Após, percorra a lista e calcule a soma e a multiplicação dos números. Ao final, mostre os números lidos, a soma dos números e a multiplicação entre eles.

# %%
lst = []
soma = 0
mult = 1

for i in range(5):
  num = int(input(f'Digite o {i+1}º número inteiro de sua preferência: '))
  
  lst.append(num)

for i in lst:
  soma += i
  mult *= i
  
print('\n')
print(f'Os números escolhidos são: {lst}')
print(f'A soma desses números é igual a: {soma}')
print(f'A multiplicação desses números é igual a: {mult}')
# Out:
# Digite o 1º número inteiro de sua preferência: 5
# Digite o 2º número inteiro de sua preferência: 10
# Digite o 3º número inteiro de sua preferência: 2
# Digite o 4º número inteiro de sua preferência: 1
# Digite o 5º número inteiro de sua preferência: 9
#
#
# Os números escolhidos são: [5, 10, 2, 1, 9]
# A soma desses números é igual a: 27
# A multiplicação desses números é igual a: 900

# %%
# solução professor
numeros = []
for i in range(5):
  numeros.append(int(input(f'Digite o {i+1}º número: ')))

soma = 0
mult = 1

for x in numeros:
  soma += x
  mult *= x

for x in numeros:
  print(x, end = ' ')

print(f'\nA soma dos números foi {soma}.')
print(f'\nA multiplicação dos números foi {mult}.')
# Out:
# Digite o 1º número: 5
# Digite o 2º número: 9
# Digite o 3º número: 7
# Digite o 4º número: 3
# Digite o 5º número: 6
# 5 9 7 3 6
# A soma dos números foi 30.
#
# A multiplicação dos números foi 5670.

# %% [markdown]
# 7) Faça um Programa que leia uma lista A com 10 números inteiros, calcule e mostre a soma dos quadrados dos elementos da lista.

# %%
lst = []
soma = 0

for i in range(10):
  num = int(input(f'Digite o {i+1}º número inteiro de sua preferência: '))
  
  lst.append(num)

for i in lst:
  i = i ** 2
  soma += i
  
print('\n')
print(f'Os números escolhidos são: {lst}')
print(f'A soma dos quadrados desses números é igual a: {soma}')
# Out:
# Digite o 1º número inteiro de sua preferência: 2
# Digite o 2º número inteiro de sua preferência: 2
# Digite o 3º número inteiro de sua preferência: 2
# Digite o 4º número inteiro de sua preferência: 2
# Digite o 5º número inteiro de sua preferência: 2
#
#
# Os números escolhidos são: [2, 2, 2, 2, 2]
# A soma dos quadrados desses números é igual a: 20

# %%
# solução professor

A = []

for i in range(10):
  A.append(int(input(f'Digite o {i+1}º número: ')))

for x in A:
  soma += x**2

print(f"A soma dos quadrados dos elementos da lista é {soma}.")
# Out:
# Digite o 1º número: 2
# Digite o 2º número: 2
# Digite o 3º número: 2
# Digite o 4º número: 2
# Digite o 5º número: 2
# Digite o 6º número: 2
# Digite o 7º número: 2
# Digite o 8º número: 2
# Digite o 9º número: 2
# Digite o 10º número: 2
# A soma dos quadrados dos elementos da lista é 70.

# %% [markdown]
# 8) Faça um programa que leia o nome, a idade e a altura de 10 alunos da SoulCode. Em seguida determine quantos alunos com mais de 13 anos possuem altura inferior à média de altura desses alunos.

# %%
nomes = []
idades = []
alturas = []
soma = 0
j = 0

for i in range(10):
  aluno = input(f"\nDigite o nome do {i+1}º aluno: ")
  nomes.append(aluno)
  idade = int(input(f"Digite a idade do {i+1}º aluno: "))
  idades.append(idade)
  altura = float(input(f"Digite a altura do {i+1}º aluno: "))
  alturas.append(altura)

for i in alturas:       
  soma += i
  media = soma / 10

for i in idades:
  if i > 13:
    n = idades.index(i)
    if alturas[n] < media:
      j += 1

print("\n")
print(f"A média das alturas é: {media:.2f}")
print(f"{j} aluno(s) com mais de 13 anos possuem altura inferior à média.")
# Out:
# Digite o nome do 1º aluno: Giovana
# Digite a idade do 1º aluno: 15
# Digite a altura do 1º aluno: 1.54
#
# Digite o nome do 2º aluno: Rafael
# Digite a idade do 2º aluno: 16
# Digite a altura do 2º aluno: 1.80
#
# Digite o nome do 3º aluno: Mateus
# Digite a idade do 3º aluno: 12
# Digite a altura do 3º aluno: 1.75
#
# Digite o nome do 4º aluno: Maria
# Digite a idade do 4º aluno: 14
# Digite a altura do 4º aluno: 1.71
#
#
# A média das alturas é: 1.70
# 1 aluno(s) com mais de 13 anos possuem altura inferior à média.

# %%
# solução professor
nomes = []
idades = []
alturas = []
soma_alturas = 0
qtd = 0

for i in range(10):
  nomes.append(input(f"\nDigite o nome do {i+1}º aluno: "))
  idades.append(int(input(f"Digite a idade do {i+1}º aluno: ")))
  altura = float(input(f"Digite a altura do {i+1}º aluno: "))
  soma_alturas += altura
  alturas.append(altura)

media_altura = soma_alturas / len(alturas)

for i in range(len(nomes)):
  if idades[i] > 13 and alturas[i] < media_altura:
    qtd += 1

print(f'A quantidade de alunos com mais de 13 anos que são menores que a média {media_altura} é {qtd}.')

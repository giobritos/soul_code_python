# %% [markdown]
# ## Importação das Bibliotecas

# %%
# o pymongo já vem nas versões mais atuais do colab, porém caso necessário:
#pip install pymongo[srv]

# %%
import pymongo 
from pymongo import MongoClient

# %% [markdown]
# ## Conector do Mongo Atlas

# %%
# conector do mongo atlas
uri = "mongodb+srv://giovana-soulcode.quvpom8.mongodb.net/?authSource=%24external&authMechanism=MONGODB-X509&retryWrites=true&w=majority"
client = MongoClient(uri, tls=True, tlsCertificateKeyFile='/content/drive/MyDrive/X509-cert-7346878477947766211.pem')

# %%
# escolha do database e colecao
db = client['Aula1']
colecao = db['primeira']

# %%
# verificar conexão / Qtd. documentos da coleção
colecao.count_documents({})
# Out:
# 61

# %% [markdown]
# ## Create

# %%
# cria uma entrada
colecao.insert_one({'nome':'GIOVANA DE BRITO SILVA','idade':33,'salario':1300})

# %%
colecao.insert_one({'nome':'BISMARK PROF','idade':32,'salario':1800})

# %%
colecao.insert_one({'nome':'IRGO PROF','idade':33})

# %%
# cria várias entradas de uma vez
colecao.insert_many([{'nome':'Suzana','idade':31},{'nome':'Paulo','idade':23}])

# %%
colecao.insert_many([{'nome':'Ivana','idade':35},{'nome':'Laisa','idade':25},{'nome':'Mariana','idade':18},{'nome':'Laura','salario':1300},{'nome':'Lucas','salario':1850}])

# %%
colecao.insert_one({'nome':'juliana','idade':45,'salario':3500})

# %%
colecao.insert_one({'nome':'Nayara','idade':28,'salario':2200})

# %%
colecao.insert_one({'nome':'Jorge','idade':15})

# %%
colecao.insert_one({'salario':1500,'idade':18})

# %%
colecao.insert_many([{'salario':3500,'idade':40},{'nome':'Jose','idade':24},{'nome':'Felipe','dia':'2022-12-01'}])

# %%
# retorna id do documento criado
dados = {'nome':'Paulo 2','idade':45}
info = colecao.insert_one(dados)
print(info.inserted_id)
# Out:
# 63890ce82e0ad5018164d3be

# %%
# preenchendo nosso db criando documentos randomicos
n = 10
y = 20

while n < 50:
  dados = {'nome':'cliente '+str(y), 'idade':n}
  i = colecao.insert_one(dados)
  n += 1
  y -= 1
  print(i.inserted_id)
# Out:
# 63890eb72e0ad5018164d3bf
# 63890eb72e0ad5018164d3c0
# 63890eb72e0ad5018164d3c1
# 63890eb72e0ad5018164d3c2
# 63890eb72e0ad5018164d3c3
# 63890eb72e0ad5018164d3c4
# 63890eb82e0ad5018164d3c5
# 63890eb82e0ad5018164d3c6
# 63890eb82e0ad5018164d3c7
# 63890eb82e0ad5018164d3c8
# 63890eb82e0ad5018164d3c9
# 63890eb82e0ad5018164d3ca
# 63890eb82e0ad5018164d3cb
# 63890eb82e0ad5018164d3cc
# 63890eb82e0ad5018164d3cd
# 63890eb92e0ad5018164d3ce
# 63890eb92e0ad5018164d3cf
# 63890eb92e0ad5018164d3d0
# 63890eb92e0ad5018164d3d1
# 63890eb92e0ad5018164d3d2
# 63890eb92e0ad5018164d3d3
# 63890eb92e0ad5018164d3d4
# 63890eb92e0ad5018164d3d5
# 63890eba2e0ad5018164d3d6
# 63890eba2e0ad5018164d3d7
# 63890eba2e0ad5018164d3d8
# 63890eba2e0ad5018164d3d9
# 63890eba2e0ad5018164d3da
# 63890eba2e0ad5018164d3db
# 63890eba2e0ad5018164d3dc
# 63890eba2e0ad5018164d3dd
# 63890ebb2e0ad5018164d3de
# 63890ebb2e0ad5018164d3df
# 63890ebb2e0ad5018164d3e0
# 63890ebb2e0ad5018164d3e1
# 63890ebb2e0ad5018164d3e2
# 63890ebb2e0ad5018164d3e3
# ...

# %% [markdown]
# ## Read

# %%
# buscar arquivos em toda a coleção
for x in colecao.find():
  print(x)
# Out:
# {'_id': ObjectId('6388ff9e2e0ad5018164d3aa'), 'nome': 'GIOVANA DE BRITO SILVA', 'idade': 33, 'salario': 1300}
# {'_id': ObjectId('6388ffde2e0ad5018164d3ab'), 'nome': 'GIOVANA DE BRITO SILVA', 'idade': 33, 'salario': 1300}
# {'_id': ObjectId('638900492e0ad5018164d3ac'), 'nome': 'BISMARK PROF', 'idade': 32, 'salario': 1800}
# {'_id': ObjectId('638900c62e0ad5018164d3ad'), 'nome': 'BISMARK PROF', 'idade': 32, 'salario': 1800}
# {'_id': ObjectId('638901b42e0ad5018164d3ae'), 'nome': 'IRGO PROF', 'idade': 33, 'salario': 2000}
# {'_id': ObjectId('638901d42e0ad5018164d3af'), 'nome': 'IRGO PROF', 'idade': 33}
# {'_id': ObjectId('638905442e0ad5018164d3b0'), 'nome': 'Suzana', 'idade': 31}
# {'_id': ObjectId('638905442e0ad5018164d3b1'), 'nome': 'Paulo', 'idade': 23}
# {'_id': ObjectId('638909432e0ad5018164d3b2'), 'nome': 'Ivana', 'idade': 35}
# {'_id': ObjectId('638909432e0ad5018164d3b3'), 'nome': 'Laisa', 'idade': 25}
# ...

# %%
# localizar por parametro de número
# $gt = maior que
# $gte = maior ou igual a
busca = {'idade':{'$gt':30}}

doc = colecao.find(busca)

for x in doc:
  print(x)
# Out:
# {'_id': ObjectId('6388ff9e2e0ad5018164d3aa'), 'nome': 'GIOVANA DE BRITO SILVA', 'idade': 33, 'salario': 1300}
# {'_id': ObjectId('6388ffde2e0ad5018164d3ab'), 'nome': 'GIOVANA DE BRITO SILVA', 'idade': 33, 'salario': 1300}
# {'_id': ObjectId('638900492e0ad5018164d3ac'), 'nome': 'BISMARK PROF', 'idade': 32, 'salario': 1800}
# {'_id': ObjectId('638900c62e0ad5018164d3ad'), 'nome': 'BISMARK PROF', 'idade': 32, 'salario': 1800}
# {'_id': ObjectId('638901b42e0ad5018164d3ae'), 'nome': 'IRGO PROF', 'idade': 33, 'salario': 2000}
# {'_id': ObjectId('638901d42e0ad5018164d3af'), 'nome': 'IRGO PROF', 'idade': 33}
# {'_id': ObjectId('638905442e0ad5018164d3b0'), 'nome': 'Suzana', 'idade': 31}
# {'_id': ObjectId('638909432e0ad5018164d3b2'), 'nome': 'Ivana', 'idade': 35}
# {'_id': ObjectId('638909662e0ad5018164d3b7'), 'nome': 'juliana', 'idade': 45, 'salario': 3500}
# {'_id': ObjectId('638909fd2e0ad5018164d3bb'), 'salario': 3500, 'idade': 40}
# ...

# %%
# localizar por parametro de número
# $lt = menor que 
# $lte = menor e igual a
busca = {'idade':{'$lte':30}}

doc = colecao.find(busca)

for x in doc:
  print(x)
# Out:
# {'_id': ObjectId('638905442e0ad5018164d3b1'), 'nome': 'Paulo', 'idade': 23}
# {'_id': ObjectId('638909432e0ad5018164d3b3'), 'nome': 'Laisa', 'idade': 25}
# {'_id': ObjectId('638909432e0ad5018164d3b4'), 'nome': 'Mariana', 'idade': 18}
# {'_id': ObjectId('638909782e0ad5018164d3b8'), 'nome': 'Nayara', 'idade': 28, 'salario': 2200}
# {'_id': ObjectId('638909832e0ad5018164d3b9'), 'nome': 'Jorge', 'idade': 15}
# {'_id': ObjectId('638909982e0ad5018164d3ba'), 'salario': 1500, 'idade': 18}
# {'_id': ObjectId('638909fd2e0ad5018164d3bc'), 'nome': 'Jose', 'idade': 24}
# {'_id': ObjectId('63890eb72e0ad5018164d3bf'), 'nome': 'cliente 20', 'idade': 10}
# {'_id': ObjectId('63890eb72e0ad5018164d3c0'), 'nome': 'cliente 19', 'idade': 11}
# {'_id': ObjectId('63890eb72e0ad5018164d3c1'), 'nome': 'cliente 18', 'idade': 12}
# {'_id': ObjectId('63890eb72e0ad5018164d3c2'), 'nome': 'cliente 17', 'idade': 13}
# {'_id': ObjectId('63890eb72e0ad5018164d3c3'), 'nome': 'cliente 16', 'idade': 14}
# ...

# %%
# localizar por parametro de número
# $ne = diferente
busca = {'idade':{'$ne':[20,30,40]}}

doc = colecao.find(busca)

for x in doc:
  print(x)
# Out:
# {'_id': ObjectId('6388ff9e2e0ad5018164d3aa'), 'nome': 'GIOVANA DE BRITO SILVA', 'idade': 33, 'salario': 1300}
# {'_id': ObjectId('6388ffde2e0ad5018164d3ab'), 'nome': 'GIOVANA DE BRITO SILVA', 'idade': 33, 'salario': 1300}
# {'_id': ObjectId('638900492e0ad5018164d3ac'), 'nome': 'BISMARK PROF', 'idade': 32, 'salario': 1800}
# {'_id': ObjectId('638900c62e0ad5018164d3ad'), 'nome': 'BISMARK PROF', 'idade': 32, 'salario': 1800}
# {'_id': ObjectId('638901b42e0ad5018164d3ae'), 'nome': 'IRGO PROF', 'idade': 33, 'salario': 2000}
# {'_id': ObjectId('638901d42e0ad5018164d3af'), 'nome': 'IRGO PROF', 'idade': 33}
# {'_id': ObjectId('638905442e0ad5018164d3b0'), 'nome': 'Suzana', 'idade': 31}
# {'_id': ObjectId('638905442e0ad5018164d3b1'), 'nome': 'Paulo', 'idade': 23}
# {'_id': ObjectId('638909432e0ad5018164d3b2'), 'nome': 'Ivana', 'idade': 35}
# {'_id': ObjectId('638909432e0ad5018164d3b3'), 'nome': 'Laisa', 'idade': 25}
# ...

# %%
# localizar por parametro de número
busca = {'idade':20}

doc = colecao.find(busca)

for x in doc:
  print(x)
# Out:
# {'_id': ObjectId('63890eb82e0ad5018164d3c9'), 'nome': 'cliente 10', 'idade': 20}

# %%
# localizar por parametro de texto
busca = {'nome':'cliente 10'}

doc = colecao.find(busca)

for x in doc:
  print(x)
# Out:
# {'_id': ObjectId('63890eb82e0ad5018164d3c9'), 'nome': 'cliente 10', 'idade': 20}

# %%
# localizar por parametro em lista
busca = {'nome':{'$in':['cliente 10','cliente 2','cliente 3']}}

doc = colecao.find(busca)

for x in doc:
  print(x)
# Out:
# {'_id': ObjectId('63890eb82e0ad5018164d3c9'), 'nome': 'cliente 10', 'idade': 20}
# {'_id': ObjectId('63890eb92e0ad5018164d3d0'), 'nome': 'cliente 3', 'idade': 27}
# {'_id': ObjectId('63890eb92e0ad5018164d3d1'), 'nome': 'cliente 2', 'idade': 28}

# %%
# localizar por parametro em lista
busca = {'idade':{'$in':[18, 19]}}

doc = colecao.find(busca)

for x in doc:
  print(x)
# Out:
# {'_id': ObjectId('638909432e0ad5018164d3b4'), 'nome': 'Mariana', 'idade': 18}
# {'_id': ObjectId('638909982e0ad5018164d3ba'), 'salario': 1500, 'idade': 18}
# {'_id': ObjectId('63890eb82e0ad5018164d3c7'), 'nome': 'cliente 12', 'idade': 18}
# {'_id': ObjectId('63890eb82e0ad5018164d3c8'), 'nome': 'cliente 11', 'idade': 19}

# %%
# localizar por parametro fechado
busca = {'nome':'cliente 12', 'idade':18}

doc = colecao.find(busca)

for x in doc:
  print(x)
# Out:
# {'_id': ObjectId('63890eb82e0ad5018164d3c7'), 'nome': 'cliente 12', 'idade': 18}

# %%
# localizar por parametro ou
busca = {'$or':[{'nome':'GIOVANA DE BRITO SILVA'},{'idade':25}]}

doc = colecao.find(busca)

for x in doc:
  print(x)
# Out:
# {'_id': ObjectId('6388ff9e2e0ad5018164d3aa'), 'nome': 'GIOVANA DE BRITO SILVA', 'idade': 33, 'salario': 1300}
# {'_id': ObjectId('6388ffde2e0ad5018164d3ab'), 'nome': 'GIOVANA DE BRITO SILVA', 'idade': 33, 'salario': 1300}
# {'_id': ObjectId('638909432e0ad5018164d3b3'), 'nome': 'Laisa', 'idade': 25}
# {'_id': ObjectId('63890eb92e0ad5018164d3ce'), 'nome': 'cliente 5', 'idade': 25}

# %%
# localizar por parametro range
busca = {'idade':{'$gt':20,'$lt':25}}

doc = colecao.find(busca)

for x in doc:
  print(x)
# Out:
# {'_id': ObjectId('638905442e0ad5018164d3b1'), 'nome': 'Paulo', 'idade': 23}
# {'_id': ObjectId('638909fd2e0ad5018164d3bc'), 'nome': 'Jose', 'idade': 24}
# {'_id': ObjectId('63890eb82e0ad5018164d3ca'), 'nome': 'cliente 9', 'idade': 21}
# {'_id': ObjectId('63890eb82e0ad5018164d3cb'), 'nome': 'cliente 8', 'idade': 22}
# {'_id': ObjectId('63890eb82e0ad5018164d3cc'), 'nome': 'cliente 7', 'idade': 23}
# {'_id': ObjectId('63890eb82e0ad5018164d3cd'), 'nome': 'cliente 6', 'idade': 24}

# %% [markdown]
# ## Update | Atualização

# %%
# atualização simples
# no caso da atualização é melhor usar o parametro many, pois o one troca apenas o primeiro
busca = {'idade':{'$gte':18}}

modifica = {'$set':{'emancipado':'SIM'}}

colecao.update_many(busca, modifica)

# %%
busca = {'idade':{'$lt':18}}

modifica = {'$set':{'emancipado':'NÃO'}}

colecao.update_many(busca, modifica)

# %%
# verificando se as alterações foram feitas
busca = {'idade':{'$gt':18}}

doc = colecao.find(busca)

for x in doc:
  print(x)
# Out:
# {'_id': ObjectId('6388ff9e2e0ad5018164d3aa'), 'nome': 'GIOVANA DE BRITO SILVA', 'idade': 33, 'salario': 1300, 'emancipado': 'SIM'}
# {'_id': ObjectId('6388ffde2e0ad5018164d3ab'), 'nome': 'GIOVANA DE BRITO SILVA', 'idade': 33, 'salario': 1300, 'emancipado': 'SIM'}
# {'_id': ObjectId('638900492e0ad5018164d3ac'), 'nome': 'BISMARK PROF', 'idade': 32, 'salario': 1800, 'emancipado': 'SIM'}
# {'_id': ObjectId('638900c62e0ad5018164d3ad'), 'nome': 'BISMARK PROF', 'idade': 32, 'salario': 1800, 'emancipado': 'SIM'}
# {'_id': ObjectId('638901b42e0ad5018164d3ae'), 'nome': 'IRGO PROF', 'idade': 33, 'salario': 2000, 'emancipado': 'SIM'}
# {'_id': ObjectId('638901d42e0ad5018164d3af'), 'nome': 'IRGO PROF', 'idade': 33, 'emancipado': 'SIM'}
# {'_id': ObjectId('638905442e0ad5018164d3b0'), 'nome': 'Suzana', 'idade': 31, 'emancipado': 'SIM'}
# {'_id': ObjectId('638905442e0ad5018164d3b1'), 'nome': 'Paulo', 'idade': 23, 'emancipado': 'SIM'}
# ...

# %%
# verificando se as alterações foram feitas
busca = {'idade':{'$lte':18}}

doc = colecao.find(busca)

for x in doc:
  print(x)
# Out:
# {'_id': ObjectId('638909432e0ad5018164d3b4'), 'nome': 'Mariana', 'idade': 18, 'emancipado': 'SIM'}
# {'_id': ObjectId('638909832e0ad5018164d3b9'), 'nome': 'Jorge', 'idade': 15, 'emancipado': 'NÃO'}
# {'_id': ObjectId('638909982e0ad5018164d3ba'), 'salario': 1500, 'idade': 18, 'emancipado': 'SIM'}
# {'_id': ObjectId('63890eb72e0ad5018164d3bf'), 'nome': 'cliente 20', 'idade': 10, 'emancipado': 'NÃO'}
# {'_id': ObjectId('63890eb72e0ad5018164d3c0'), 'nome': 'cliente 19', 'idade': 11, 'emancipado': 'NÃO'}
# {'_id': ObjectId('63890eb72e0ad5018164d3c1'), 'nome': 'cliente 18', 'idade': 12, 'emancipado': 'NÃO'}
# {'_id': ObjectId('63890eb72e0ad5018164d3c2'), 'nome': 'cliente 17', 'idade': 13, 'emancipado': 'NÃO'}
# {'_id': ObjectId('63890eb72e0ad5018164d3c3'), 'nome': 'cliente 16', 'idade': 14, 'emancipado': 'NÃO'}
# {'_id': ObjectId('63890eb72e0ad5018164d3c4'), 'nome': 'cliente 15', 'idade': 15, 'emancipado': 'NÃO'}
# ...

# %%
# atualização com or
busca = {'$or':[{'nome':'Jorge'},{'idade':27}]}

modifica = {'$set':{'achou':'SIM'}}

colecao.update_many(busca, modifica)

# %%
# verificando se as alterações foram feitas
busca = {'idade':{'$lte':28}}

doc = colecao.find(busca)

for x in doc:
  print(x)
# Out:
# {'_id': ObjectId('638905442e0ad5018164d3b1'), 'nome': 'Paulo', 'idade': 23, 'emancipado': 'SIM'}
# {'_id': ObjectId('638909432e0ad5018164d3b3'), 'nome': 'Laisa', 'idade': 25, 'emancipado': 'SIM'}
# {'_id': ObjectId('638909432e0ad5018164d3b4'), 'nome': 'Mariana', 'idade': 18, 'emancipado': 'SIM'}
# {'_id': ObjectId('638909782e0ad5018164d3b8'), 'nome': 'Nayara', 'idade': 28, 'salario': 2200, 'emancipado': 'SIM'}
# {'_id': ObjectId('638909832e0ad5018164d3b9'), 'nome': 'Jorge', 'idade': 15, 'emancipado': 'NÃO', 'achou': 'SIM'}
# {'_id': ObjectId('638909982e0ad5018164d3ba'), 'salario': 1500, 'idade': 18, 'emancipado': 'SIM'}
# {'_id': ObjectId('638909fd2e0ad5018164d3bc'), 'nome': 'Jose', 'idade': 24, 'emancipado': 'SIM'}
# {'_id': ObjectId('63890eb72e0ad5018164d3bf'), 'nome': 'cliente 20', 'idade': 10, 'emancipado': 'NÃO'}
# {'_id': ObjectId('63890eb72e0ad5018164d3c0'), 'nome': 'cliente 19', 'idade': 11, 'emancipado': 'NÃO'}
# ...

# %% [markdown]
# ## Delete | Apagar ou Deletar

# %%
# se não tiver certeza do que tiver deletando, delete apenas 1
colecao.delete_one({'nome':'IRGO PROF'})

# %%
# verificando se as alterações foram feitas
busca = {'idade':{'$gt':18}}

doc = colecao.find(busca)

for x in doc:
  print(x)
# Out:
# {'_id': ObjectId('6388ff9e2e0ad5018164d3aa'), 'nome': 'GIOVANA DE BRITO SILVA', 'idade': 33, 'salario': 1300, 'emancipado': 'SIM'}
# {'_id': ObjectId('6388ffde2e0ad5018164d3ab'), 'nome': 'GIOVANA DE BRITO SILVA', 'idade': 33, 'salario': 1300, 'emancipado': 'SIM'}
# {'_id': ObjectId('638900492e0ad5018164d3ac'), 'nome': 'BISMARK PROF', 'idade': 32, 'salario': 1800, 'emancipado': 'SIM'}
# {'_id': ObjectId('638900c62e0ad5018164d3ad'), 'nome': 'BISMARK PROF', 'idade': 32, 'salario': 1800, 'emancipado': 'SIM'}
# {'_id': ObjectId('638901d42e0ad5018164d3af'), 'nome': 'IRGO PROF', 'idade': 33, 'emancipado': 'SIM'}
# {'_id': ObjectId('638905442e0ad5018164d3b0'), 'nome': 'Suzana', 'idade': 31, 'emancipado': 'SIM'}
# {'_id': ObjectId('638905442e0ad5018164d3b1'), 'nome': 'Paulo', 'idade': 23, 'emancipado': 'SIM'}
# {'_id': ObjectId('638909432e0ad5018164d3b2'), 'nome': 'Ivana', 'idade': 35, 'emancipado': 'SIM'}
# ...

# %%
busca = {'idade':{'$lte':18}}

doc = colecao.find(busca)

for x in doc:
  print(x)
# Out:
# {'_id': ObjectId('638909432e0ad5018164d3b4'), 'nome': 'Mariana', 'idade': 18, 'emancipado': 'SIM'}
# {'_id': ObjectId('638909832e0ad5018164d3b9'), 'nome': 'Jorge', 'idade': 15, 'emancipado': 'NÃO', 'achou': 'SIM'}
# {'_id': ObjectId('638909982e0ad5018164d3ba'), 'salario': 1500, 'idade': 18, 'emancipado': 'SIM'}
# {'_id': ObjectId('63890eb72e0ad5018164d3bf'), 'nome': 'cliente 20', 'idade': 10, 'emancipado': 'NÃO'}
# {'_id': ObjectId('63890eb72e0ad5018164d3c0'), 'nome': 'cliente 19', 'idade': 11, 'emancipado': 'NÃO'}
# {'_id': ObjectId('63890eb72e0ad5018164d3c1'), 'nome': 'cliente 18', 'idade': 12, 'emancipado': 'NÃO'}
# {'_id': ObjectId('63890eb72e0ad5018164d3c2'), 'nome': 'cliente 17', 'idade': 13, 'emancipado': 'NÃO'}
# {'_id': ObjectId('63890eb72e0ad5018164d3c3'), 'nome': 'cliente 16', 'idade': 14, 'emancipado': 'NÃO'}
# {'_id': ObjectId('63890eb72e0ad5018164d3c4'), 'nome': 'cliente 15', 'idade': 15, 'emancipado': 'NÃO'}
# ...

# %%
colecao.delete_one({'emancipado':'NÃO'})

# %%
busca = {'idade':{'$lte':18}}

doc = colecao.find(busca)

for x in doc:
  print(x)
# Out:
# {'_id': ObjectId('638909432e0ad5018164d3b4'), 'nome': 'Mariana', 'idade': 18, 'emancipado': 'SIM'}
# {'_id': ObjectId('638909982e0ad5018164d3ba'), 'salario': 1500, 'idade': 18, 'emancipado': 'SIM'}
# {'_id': ObjectId('63890eb72e0ad5018164d3bf'), 'nome': 'cliente 20', 'idade': 10, 'emancipado': 'NÃO'}
# {'_id': ObjectId('63890eb72e0ad5018164d3c0'), 'nome': 'cliente 19', 'idade': 11, 'emancipado': 'NÃO'}
# {'_id': ObjectId('63890eb72e0ad5018164d3c1'), 'nome': 'cliente 18', 'idade': 12, 'emancipado': 'NÃO'}
# {'_id': ObjectId('63890eb72e0ad5018164d3c2'), 'nome': 'cliente 17', 'idade': 13, 'emancipado': 'NÃO'}
# {'_id': ObjectId('63890eb72e0ad5018164d3c3'), 'nome': 'cliente 16', 'idade': 14, 'emancipado': 'NÃO'}
# {'_id': ObjectId('63890eb72e0ad5018164d3c4'), 'nome': 'cliente 15', 'idade': 15, 'emancipado': 'NÃO'}
# {'_id': ObjectId('63890eb82e0ad5018164d3c5'), 'nome': 'cliente 14', 'idade': 16, 'emancipado': 'NÃO'}
# ...

# %%
colecao.delete_many({'emancipado':'NÃO'})

# %%
busca = {'idade':{'$lte':18}}

doc = colecao.find(busca)

for x in doc:
  print(x)
# Out:
# {'_id': ObjectId('638909432e0ad5018164d3b4'), 'nome': 'Mariana', 'idade': 18, 'emancipado': 'SIM'}
# {'_id': ObjectId('638909982e0ad5018164d3ba'), 'salario': 1500, 'idade': 18, 'emancipado': 'SIM'}
# {'_id': ObjectId('63890eb82e0ad5018164d3c7'), 'nome': 'cliente 12', 'idade': 18, 'emancipado': 'SIM'}

# %%
# dropa toda a colecao
colecao.drop()

# %% [markdown]
# ## Integração com Pandas

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Extrair do Mongo

# %%
# extrair de uma colecao
cursor = colecao.find({})
dfmongo = pd.DataFrame(list(cursor))

# %%
dfmongo
# Out:
#                          _id                    nome  idade  salario  \
# 0   6388ff9e2e0ad5018164d3aa  GIOVANA DE BRITO SILVA   33.0   1300.0
# 1   6388ffde2e0ad5018164d3ab  GIOVANA DE BRITO SILVA   33.0   1300.0
# 2   638900492e0ad5018164d3ac            BISMARK PROF   32.0   1800.0
# 3   638900c62e0ad5018164d3ad            BISMARK PROF   32.0   1800.0
# 4   638901d42e0ad5018164d3af               IRGO PROF   33.0      NaN
# 5   638905442e0ad5018164d3b0                  Suzana   31.0      NaN
# 6   638905442e0ad5018164d3b1                   Paulo   23.0      NaN
# 7   638909432e0ad5018164d3b2                   Ivana   35.0      NaN
# 8   638909432e0ad5018164d3b3                   Laisa   25.0      NaN
# 9   638909432e0ad5018164d3b4                 Mariana   18.0      NaN
# 10  638909432e0ad5018164d3b5                   Laura    NaN   1300.0
# 11  638909432e0ad5018164d3b6                   Lucas    NaN   1850.0
# 12  638909662e0ad5018164d3b7                 juliana   45.0   3500.0
# ...

# %%
dfmongo.dtypes
# Out:
# _id            object
# nome           object
# idade         float64
# salario       float64
# emancipado     object
# dia            object
# achou          object
# dtype: object

# %% [markdown]
# ## Base Cenipa Tratada

# %%
df = pd.read_csv('https://storage.googleapis.com/aulas-bc26-dados-gbs/cenipa/ocorrencia.csv', sep=';', encoding='ISO-8859-1', parse_dates=['ocorrencia_dia'], dayfirst=True)

# %%
# dropagem das colunas que tinham dados repetidos
df.drop(['codigo_ocorrencia1','codigo_ocorrencia2','codigo_ocorrencia3','codigo_ocorrencia4'],axis=1,inplace=True)
# drop de colunas que não serão utilizadas
df.drop(['ocorrencia_latitude','ocorrencia_longitude','investigacao_aeronave_liberada','investigacao_status','divulgacao_relatorio_numero','divulgacao_relatorio_publicado','divulgacao_dia_publicacao'],axis=1,inplace=True)

# %%
# renomear as colunas
df.rename(columns={'codigo_ocorrencia':'ocorrencia','ocorrencia_classificacao':'classificacao','ocorrencia_cidade':'cidade','ocorrencia_uf':'uf','ocorrencia_pais':'pais','ocorrencia_aerodromo':'aerodromo'},inplace=True)
df.rename(columns={'ocorrencia_dia':'dia','ocorrencia_hora':'horario','total_recomendacoes':'recomendacoes','total_aeronaves_envolvidas':'n_aeronaves','ocorrencia_saida_pista':'saida_pista'},inplace=True)

# %%
df.replace(['***','**NI'],pd.NA,inplace=True)

# %%
df.replace(pd.NA,np.NaN,inplace=True)

# %% [markdown]
# ## Enviar DataFrame pro Mongo

# %%
db2 = client['cenipa']
colecaocenipa = db2['tratado']
colecaocenipa.count_documents({})
# Out:
# 0

# %%
# enviar o DF para colecao selecionada no mongo
df_dict = df.to_dict("records")

colecaocenipa.insert_many(df_dict)

# %%
colecaocenipa.count_documents({})
# Out:
# 6769

# %%
for x in colecaocenipa.find():
  print(x)

# %%
cursor = colecaocenipa.find({})
dfcenipa = pd.DataFrame(list(cursor))

# %%
dfcenipa
# Out:
#                            _id  ocorrencia    classificacao  \
# 0     638a072e9786f9b54c5c1782       81027  INCIDENTE GRAVE
# 1     638a072e9786f9b54c5c1783       81030        INCIDENTE
# 2     638a072e9786f9b54c5c1784       81023  INCIDENTE GRAVE
# 3     638a072e9786f9b54c5c1785       81029        INCIDENTE
# 4     638a072e9786f9b54c5c1786       81025        INCIDENTE
# ...                        ...         ...              ...
# 6764  638a072e9786f9b54c5c31ee       40324        INCIDENTE
# 6765  638a072e9786f9b54c5c31ef       39527         ACIDENTE
# 6766  638a072e9786f9b54c5c31f0       40211        INCIDENTE
# 6767  638a072e9786f9b54c5c31f1       40349        INCIDENTE
# 6768  638a072e9786f9b54c5c31f2       40351        INCIDENTE
#
#                   cidade  uf    pais aerodromo        dia   horario  \
# 0              SÃO PAULO  SP  BRASIL      SBSP 2022-10-09  16:30:00
# 1                VITÓRIA  ES  BRASIL      SBVT 2022-10-09  16:20:00
# ...

# %% [markdown]
# ## Extraindo Base Cenipa Ocorrência e Enviando para o Mongo

# %%
df_ocor = pd.read_csv('https://storage.googleapis.com/aulas-bc26-dados-gbs/cenipa/ocorrencia.csv', sep=';', encoding='ISO-8859-1')

# %%
dboriginal = client['cenipa']
colecaocenipa_ocor = dboriginal['stratamento']
colecaocenipa_ocor.count_documents({})
# Out:
# 0

# %%
# enviar o DF para colecao selecionada no mongo
df_ocor_dict = df_ocor.to_dict("records")

colecaocenipa_ocor.insert_many(df_ocor_dict)

# %%
colecaocenipa_ocor.count_documents({})
# Out:
# 6769

# %%
for x in colecaocenipa_ocor.find():
  print(x)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
cursor = colecaocenipa_ocor.find({})
dfcenipa_ocor = pd.DataFrame(list(cursor))

# %%
dfcenipa_ocor
# Out:
#                            _id  codigo_ocorrencia  codigo_ocorrencia1  \
# 0     638a11479786f9b54c5c31f3              81027               81027
# 1     638a11479786f9b54c5c31f4              81030               81030
# 2     638a11479786f9b54c5c31f5              81023               81023
# 3     638a11479786f9b54c5c31f6              81029               81029
# 4     638a11479786f9b54c5c31f7              81025               81025
# ...                        ...                ...                 ...
# 6764  638a11479786f9b54c5c4c5f              40324               40324
# 6765  638a11479786f9b54c5c4c60              39527               39527
# 6766  638a11479786f9b54c5c4c61              40211               40211
# 6767  638a11479786f9b54c5c4c62              40349               40349
# 6768  638a11479786f9b54c5c4c63              40351               40351
#
#       codigo_ocorrencia2  codigo_ocorrencia3  codigo_ocorrencia4  \
# ...

# %% [markdown]
# ## Extraindo Base Alesp Despesa e Enviando para o Mongo

# %%
df_desp = pd.read_csv('https://storage.googleapis.com/aulas-bc26-dados-gbs/alesp/alesp_desp.csv')
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (5) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
dboriginal = client['alesp_desp']
colecaoalesp_desp = dboriginal['stratamento']
colecaoalesp_desp.count_documents({})
# Out:
# 0

# %%
# enviar o DF para colecao selecionada no mongo
df_desp_dict = df_desp.to_dict("records")

colecaoalesp_desp.insert_many(df_desp_dict)

# %%
colecaoalesp_desp.count_documents({})
# Out:
# 536568

# %%
for x in colecaoalesp_desp.find():
  print(x)

# %%
cursor = colecaoalesp_desp.find({})
dfalesp_desp = pd.DataFrame(list(cursor))

# %%
dfalesp_desp
# Out:
#                              _id  Unnamed: 0   Ano  Matricula  Mes    Valor  \
# 0       638a11c99786f9b54c5c4c64           0  2015     300257    3   200.00
# 1       638a11c99786f9b54c5c4c65           1  2015     300257    3   295.40
# 2       638a11c99786f9b54c5c4c66           2  2015     300257    3  2850.00
# 3       638a11c99786f9b54c5c4c67           3  2015     300257    4   100.00
# 4       638a11c99786f9b54c5c4c68           4  2015     300257    4   195.01
# ...                          ...         ...   ...        ...  ...      ...
# 536563  638a11ce9786f9b54c647c57      536563  2007     300441    3   120.00
# 536564  638a11ce9786f9b54c647c58      536564  2007     300441    3  2096.80
# 536565  638a11ce9786f9b54c647c59      536565  2007     300441    3    13.48
# 536566  638a11ce9786f9b54c647c5a      536566  2007     300441    3    38.08
# 536567  638a11ce9786f9b54c647c5b      536567  2007     300441    3  2994.00
#
#                     CNPJ            Deputado  \
# ...

# %% [markdown]
# ## Extraindo Base Alesp Cadastro e Enviando para o Mongo

# %%
df_cad = pd.read_csv('https://storage.googleapis.com/aulas-bc26-dados-gbs/alesp/cadastro_alesp.csv')

# %%
dboriginal = client['alesp_cad']
colecaoalesp_cad = dboriginal['stratamento']
colecaoalesp_cad.count_documents({})
# Out:
# 0

# %%
# enviar o DF para colecao selecionada no mongo
df_cad_dict = df_cad.to_dict("records")

colecaoalesp_cad.insert_many(df_cad_dict)

# %%
colecaoalesp_cad.count_documents({})
# Out:
# 93

# %%
for x in colecaoalesp_cad.find():
  print(x)
# Out:
# {'_id': ObjectId('638a141a9786f9b54c647c5c'), 'IdDeputado': 549, 'IdSPL': 1000000330, 'IdUA': 20377, 'Situacao': 'EXE', 'Andar': '3º andar', 'Aniversario': '01/11', 'Biografia': '<p style="margin: 0cm 0cm 0.0001pt; background-image: initial; background-position: initial; background-size: initial; background-repeat: initial; background-attachment: initial; background-origin: initial; background-clip: initial;"><strong><span style="font-size: 9.0pt; font-family: \'Helvetica\',sans-serif; color: #121212;">Adalberto Freitas &eacute; natural de Porto Alegre - RS e reside em S&atilde;o Paulo h&aacute; 49 anos, na cidade de Itupeva, &eacute; jornalista. Freitas &eacute; reconhecido pelos trabalhos sociais que sempre desenvolveu em comunidades, em v&aacute;rias regi&otilde;es de S&atilde;o Paulo.</span></strong><span style="font-size: 9.0pt; font-family: \'Helvetica\',sans-serif; color: #121212;">&nbsp;</span></p>\n<p style="margin: 0cm 0cm 0.0001pt; background-image: initial; background-pos
# ...

# %%
cursor = colecaoalesp_cad.find({})
dfalesp_cad = pd.DataFrame(list(cursor))

# %%
dfalesp_cad
# Out:
#                          _id  IdDeputado       IdSPL   IdUA Situacao  \
# 0   638a141a9786f9b54c647c5c         549  1000000330  20377      EXE
# 1   638a141a9786f9b54c647c5d         548  1000000332  20370      EXE
# 2   638a141a9786f9b54c647c5e         547  1000000335  20455      EXE
# 3   638a141a9786f9b54c647c5f         128          39  20369      EXE
# 4   638a141a9786f9b54c647c60         546  1000000342  20399      EXE
# ..                       ...         ...         ...    ...      ...
# 88  638a141a9786f9b54c647cb4         289       13109  20414      EXE
# 89  638a141a9786f9b54c647cb5         504  1000000373  20400      EXE
# 90  638a141a9786f9b54c647cb6         503  1000000374  20447      EXE
# 91  638a141a9786f9b54c647cb7          13         448  20394      EXE
# 92  638a141a9786f9b54c647cb8         290       13098  20405      EXE
#
#        Andar Aniversario                                          Biografia  \
# ...

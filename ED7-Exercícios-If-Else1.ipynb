# %% [markdown]
# 1) Faça um programa que leia duas variáveis A e B com números inteiros. Em seguida inverta os valores de A e B. Exemplo: A = 5, B = 3 , deverá ficar assim: A = 3, B = 5

# %%
a = int(input("Digite um número inteiro para A: "))
b = int(input("Digite outro número inteiro para B: "))

print(f"O valor de A é igual a {a} e de B é igual a {b}.")

c = a
a = b
b = c

print(f"Ao inverter os valores, A é igual a {a} e B é igual a {b}.")
# Out:
# Digite um número inteiro para A: 5
# Digite outro número inteiro para B: 2
# O valor de A é igual a 5 e de B é igual a 2.
# Ao inverter os valores, A é igual a 2 e B é igual a 5.

# %% [markdown]
# 2) Faça um programa que pede duas notas de um aluno. Em seguida ele deve calcular a média do aluno e dar o seguinte resultado:
#
# - A mensagem "Aprovado", se a média alcançada for maior ou igual a sete;
# - A mensagem "Recuperação", se a média for menor do que sete.

# %%
nota1 = float(input("Digite sua primeira nota: "))
nota2 = float(input("Digite sua segunda nota: "))

media = (nota1 + nota2) / 2

if media >= 7:
  print(f"Aprovado com média {media:.2f}.")

else:
  print(f"Recuperação com média {media:.2f}.")
# Out:
# Digite sua primeira nota: 8
# Digite sua segunda nota: 9
# Aprovado com média 8.50.

# %% [markdown]
# 3) Faça um programa que lê as duas notas parciais obtidas por um aluno numa disciplina ao longo de um semestre, e calcule a sua média. A atribuição de conceitos obedece à tabela abaixo:

# %%
  '''
  Média de Aproveitamento  Conceito
  Entre 9.0 e 10.0            A
  Entre 7.5 e 9.0             B
  Entre 6.0 e 7.5             C
  Entre 4.0 e 6.0             D
  Entre 4.0 e zero            E
  '''

# %% [markdown]
# O algoritmo deve mostrar na tela as notas, a média, o conceito correspondente e a mensagem “APROVADO” se o conceito for A, B ou C ou “REPROVADO” se o conceito for D ou E.

# %%
nota1 = float(input("Digite sua primeira nota: "))
nota2 = float(input("Digite sua segunda nota: "))

media = (nota1 + nota2)/2

print(f"Sua notas foram {nota1:.2f} e {nota2:.2f}, totalizando média {media:.2f}.")

if media <= 10 and media >= 9:
  conceito = "A"  
elif media < 9 and media >= 7.5:
  conceito = "B"
elif media < 7.5 and media >= 6:
  conceito = "C"
elif media < 6 and media >= 4:
  conceito = "D"
else:
  conceito = "E"

if conceito == "A" or conceito == "B" or conceito == "C":
  situacao = "APROVADO"
else:
  situacao = "REPROVADO"

print(f"Seu conceito final é {conceito} e você foi {situacao}.")
# Out:
# Digite sua primeira nota: 5
# Digite sua segunda nota: 4
# Sua notas foram 5.00 e 4.00, totalizando média 4.50.
# Seu conceito final é D e você foi REPROVADO.

# %% [markdown]
# 4) Faça um Programa que leia 4 números inteiros e mostre o maior deles.

# %%
n1 = int(input("Digite um número inteiro: "))
n2 = int(input("Digite outro número inteiro: "))
n3 = int(input("Digite outro número inteiro: "))
n4 = int(input("Digite outro número inteiro: "))

if n1 >= n2 and n1 >= n3 and n1 >= n4:
  print(f"O maior número é {n1}!")

elif n2 >= n1 and n2 >= n3 and n2 >= n4:
  print(f"O maior número é {n2}!")

elif n3 >= n1 and n3 >= n2 and n3 >= n4:
  print(f"O maior número é {n3}!")

else:
  print(f"O maior número é {n4}!")
# Out:
# Digite um número inteiro: 5
# Digite outro número inteiro: 6
# Digite outro número inteiro: 6
# Digite outro número inteiro: 4
# O maior número é 6!

# %%
# melhores práticas (pensando em loop)
n1 = int(input("Digite um número inteiro: "))
n2 = int(input("Digite outro número inteiro: "))
n3 = int(input("Digite outro número inteiro: "))
n4 = int(input("Digite outro número inteiro: "))

maior = n1

if n2 > maior:
  maior = n2

if n3 > maior:
  maior = n3

if n4 > maior:
  maior = n4

print(f"O maior número digitado é {maior}!")
# Out:
# Digite um número inteiro: 1
# Digite outro número inteiro: 2
# Digite outro número inteiro: 3
# Digite outro número inteiro: 4
# O maior número digitado é 4!

# %% [markdown]
# 5) Faça um Programa que pergunte em que turno você estuda. Peça para digitar M-matutino ou V-Vespertino ou N- Noturno. Imprima a mensagem "Bom Dia!", "Boa Tarde!" ou "Boa Noite!" ou "Valor Inválido!", conforme o caso.

# %%
print("--- BEM-VINDO ---")
print("M - Se você estuda no período matutino")
print("V - Se você estuda no período vespertino")
print("N - Se você estuda no período noturno")

turno = input("Digite a letra referente ao seu turno: ")

if turno == "M" or turno == "m":
  print("Bom dia!")

elif turno == "V" or turno == "v":
  print("Boa tarde!")

elif turno == "N" or turno == "n":
  print("Boa noite!")
  
else: 
  print("Valor inválido!")
# Out:
# --- BEM-VINDO ---
# M - Se você estuda no período matutino
# V - Se você estuda no período vespertino
# N - Se você estuda no período noturno
# Digite a letra referente ao seu turno: n
# Boa noite!

# %% [markdown]
# 6) Faça um Programa que peça um número correspondente a um determinado ano e em seguida informe se este ano é ou não bissexto. Para que um ano seja Bissexto ele tem que seguir aos seguintes critérios:
#
# Ser múltiplo de 4 e não ser múltiplo de 100 ou ser múltiplo de 400.

# %%
ano = int(input("Digite um ano de sua preferência: "))

if (ano % 4 == 0 and not ano % 100 == 0) or ano % 400 == 0:
  print(f"{ano} é um ano Bissexto!")

else:
  print(f"{ano} não é um ano Bissexto!")
# Out:
# Digite um ano de sua preferência: 2024
# 2024 é um ano Bissexto!

# %% [markdown]
# 7) Um posto está vendendo combustíveis com a seguinte tabela de descontos:
#
# Álcool:
# - até 20 litros, desconto de 3% por litro
# - acima de 20 litros, desconto de 5% por litro
#
# Gasolina:
# - até 20 litros, desconto de 4% por litro
# - acima de 20 litros, desconto de 6% por litro
#
# Escreva um algoritmo que leia o número de litros vendidos, o tipo de combustível (codificado da seguinte forma: A-álcool, G-gasolina), calcule e imprima o valor a ser pago pelo cliente sabendo-se que o preço do litro da gasolina é R 5,50 e o preço do litro do álcool é R 3,90.

# %%
print("--- BEM-VINDO ---")
print("Opções de combustível: ")
print("A - Se você irá abastecer álcool")
print("G - Se você irá abastecer gasolina")

tipo_comb = input("Digite o tipo de combustível que você abastecerá: ")
litros = float(input("Digite quantos litros você abastecerá: "))

if tipo_comb == "A" or tipo_comb == 'a' and litros <= 20:
  total = litros * 3.9 
  val_desc = total - (total * 0.03)

  print(f"O valor a ser pago é de R${val_desc:.2f}.")

elif tipo_comb == "A" or tipo_comb == 'a' and litros > 20:
  total = litros * 3.9 
  val_desc = total - (total * 0.05)

  print(f"O valor a ser pago é de R${val_desc:.2f}.")

elif tipo_comb == "G" or tipo_comb == 'g' and litros <= 20:
  total = litros * 5.5 
  val_desc = total - (total * 0.04)

  print(f"O valor a ser pago é de R${val_desc:.2f}.")

elif tipo_comb == "G" or tipo_comb == 'g' and litros > 20:
  total = litros * 5.5 
  val_desc = total - (total * 0.06)

  print(f"O valor a ser pago é de R${val_desc:.2f}.")

else:
  print("Tipo de combustível inválido!")
# Out:
# --- BEM-VINDO ---
# Opções de combustível:
# A - Se você irá abastecer álcool
# G - Se você irá abastecer gasolina
# Digite o tipo de combustível que você abastecerá: g
# Digite quantos litros você abastecerá: 10
# O valor a ser pago é de R$52.80.

# %%
print("--- BEM-VINDO ---")
print("Opções de combustível: ")
print("A - Se você irá abastecer álcool")
print("G - Se você irá abastecer gasolina")

tipo_comb = input("Digite o tipo de combustível que você abastecerá: ")
litros = float(input("Digite quantos litros você abastecerá: "))

if tipo_comb == "A" or tipo_comb == 'a': 
  tipo_comb = "Álcool"
  total = litros * 3.9
  if litros <= 20:
     val_desc = total - (total * 0.03)
  else:
    val_desc = total - (total * 0.05)

if tipo_comb == "G" or tipo_comb == 'g':
  tipo_comb = "Gasolina"
  total = litros * 5.5 
  if litros <= 20:
    val_desc = total - (total * 0.04)
  else:
    val_desc = total - (total * 0.06)

print(f"O valor a ser pago por {litros} litros de {tipo_comb} é de R${val_desc:.2f}.")
# Out:
# --- BEM-VINDO ---
# Opções de combustível:
# A - Se você irá abastecer álcool
# G - Se você irá abastecer gasolina
# Digite o tipo de combustível que você abastecerá: a
# Digite quantos litros você abastecerá: 20
# O valor a ser pago por 20.0 litros de Álcool é de R$75.66.
